# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000])
with open('output_uno.txt', 'r') as f:
    for cl, l in enumerate(f):
        if cl == 0:
            y = np.array([int(x) for x in l.split()], dtype = np.int64)

# y = np.array([2162533, 4299470, 21273643, 42480559, 215049494, 426865036, 2155039303 ,4449638352 ])
plt.figure(figsize=(12, 8))
plt.plot(x, y, 'bo', markersize=10, markeredgewidth=2, markeredgecolor='darkblue')
plt.xscale('log')
plt.yscale('log')
log_x = np.log10(x)
log_y = np.log10(y)
coeffs = np.polyfit(log_x, log_y, 1)
k, b = coeffs
x_fit = np.logspace(np.log10(min(x)), np.log10(max(x)), 100)
y_fit = 10**b * x_fit**k
plt.xlabel('log N', fontsize=14)
plt.ylabel('log T/ns', fontsize=14)
custom_xticks = [500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000]
custom_xtick_labels = [f'{np.log10(val):.2f}' for val in custom_xticks]
plt.xticks(custom_xticks, custom_xtick_labels, fontsize=12)
custom_yticks = [1e6, 1e7, 1e8, 1e9, 1e10]
custom_ytick_labels = [f'{np.log10(val):.2f}' for val in custom_yticks]
plt.yticks(custom_yticks, custom_ytick_labels, fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)
plt.grid(True, which='major', linewidth=1, alpha=0.5)
print(k)
u = np.delete(log_x, [0, 1, 2])
v = np.delete(log_y, [0, 1, 2])
c = np.polyfit(u, v, 1)
k1, b1 = c
print(k1)
x_fit1 = np.logspace(np.log10(min(x)), np.log10(max(x)), 100)
y_fit1 = 10**b1 * x_fit1**k1
plt.plot(x_fit1, y_fit1, 'b-', linewidth=2)
plt.tight_layout()
plt.savefig('1.simple.pdf', bbox_inches='tight', facecolor='white')
plt.show()
# Out:
# 0.8506748976020633
# 0.9987799899383075

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000])
# y = np.array([43564402, 49874358, 67325621, 72796231 ,98220683, 110569052 ,136815195 ,146256571 ])
with open('output_uno.txt', 'r') as f:
    for cl, l in enumerate(f):
        if cl == 1:
            y = np.array([int(x) for x in l.split()], dtype = np.int64)

plt.figure(figsize=(12, 8))
plt.plot(x, y, 'bo', markersize=10, markeredgewidth=2, markeredgecolor='darkblue')
plt.xscale('log')
plt.xlabel('log N', fontsize=14)
custom_xticks = [500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000]
custom_xtick_labels = [f'{np.log10(val):.2f}' for val in custom_xticks]
plt.xticks(custom_xticks, custom_xtick_labels, fontsize=12)
plt.ylabel('T, ns', fontsize=14)
custom_yticks = [5e7, 7.5e7, 1e8, 1.25e8, 1.5e8]
custom_ytick_labels = [5e7, 7.5e7, 1e8, 1.25e8, 1.5e8]
plt.yticks(custom_yticks, custom_ytick_labels, fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)
plt.grid(True, which='major', linewidth=1, alpha=0.5)
plt.tight_layout()
plt.savefig('1.binary.pdf', bbox_inches='tight', facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([500, 1000, 5000, 10000, 50000, 100000, 200000])
# y = np.array([2146000, 8532000, 207853000 ,823942000 ,20250292000, 79321725000, 327598910000 ])
with open('output_dos.txt', 'r') as f:
    for cl, l in enumerate(f):
        if cl == 0:
            y = np.array([int(x) for x in l.split()], dtype = np.int64)

plt.figure(figsize=(12, 8))
plt.plot(x, y, 'bo', markersize=10, markeredgewidth=2, markeredgecolor='darkblue')
plt.xscale('log')
plt.yscale('log')
log_x = np.log10(x)
log_y = np.log10(y)
coeffs = np.polyfit(log_x, log_y, 1)
k, b = coeffs
plt.xlabel('log N', fontsize=14)
plt.ylabel('log T/mcs', fontsize=14)
custom_xticks = [500, 1000, 5000, 10000, 50000, 100000, 200000]
custom_xtick_labels = [f'{np.log10(val):.2f}' for val in custom_xticks]
plt.xticks(custom_xticks, custom_xtick_labels, fontsize=12)
custom_yticks = [1e4, 1e5, 1e6, 1e7, 1e8, 1e9, 1e10, 1e11, 1e12]
custom_ytick_labels = [f'{np.log10(val):.2f}' for val in custom_yticks]
plt.yticks(custom_yticks, custom_ytick_labels, fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)
plt.grid(True, which='major', linewidth=1, alpha=0.5)
print(k)
u = np.delete(log_x, [0, 1])
v = np.delete(log_y, [0, 1])
c = np.polyfit(u, v, 1)
k1, b1 = c
print(k1)
x_fit = np.logspace(np.log10(min(x)), np.log10(max(x)), 100)
y_fit = 10**b1 * x_fit**k1
plt.plot(x_fit, y_fit, 'b-', linewidth=2)
plt.tight_layout()
plt.savefig('2.simple.pdf', bbox_inches='tight', facecolor='white')
plt.show()
# Out:
# 1.8007169276435426
# 1.9840071255713103

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000])
# y = np.array([6000, 16000, 86000, 205000, 1143000, 1864000, 4649000, 20763000 ])
with open('output_dos.txt', 'r') as f:
    for cl, l in enumerate(f):
        if cl == 1:
            y = np.array([int(x) for x in l.split()], dtype = np.int64)

plt.figure(figsize=(12, 8))
plt.plot(x, y, 'bo', markersize=10, markeredgewidth=2, markeredgecolor='darkblue')
plt.xscale('log')
plt.yscale('log')
log_x = np.log10(x)
log_y = np.log10(y)
coeffs = np.polyfit(log_x, log_y, 1)
k, b = coeffs
plt.xlabel('log N', fontsize=14)
plt.ylabel('log T/mcs', fontsize=14)
custom_xticks = [500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000]
custom_xtick_labels = [f'{np.log10(val):.2f}' for val in custom_xticks]
plt.xticks(custom_xticks, custom_xtick_labels, fontsize=12)
custom_yticks = [1e4, 1e5, 1e6, 1e7]
custom_ytick_labels = [f'{np.log10(val):.2f}' for val in custom_yticks]
plt.yticks(custom_yticks, custom_ytick_labels, fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)
plt.grid(True, which='major', linewidth=1, alpha=0.5)
print(k)
x_fit = np.logspace(np.log10(min(x)), np.log10(max(x)), 100)
y_fit = 10**b * x_fit**k
plt.plot(x_fit, y_fit, 'b-', linewidth=2)
plt.tight_layout()
plt.savefig('2.advanced.pdf', bbox_inches='tight', facecolor='white')
plt.show()
# Out:
# 0.9793695381982163

# %%
#C1
import matplotlib.pyplot as plt
import numpy as np

x = np.array([500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000])
# y = np.array([4340219, 8602143, 42476518, 85223736 ,430178692 ,856074064, 4354902370, 8890960312 ])
with open('output_tres_rnd.txt', 'r') as f:
    for cl, l in enumerate(f):
        if cl == 0:
            y = np.array([int(x) for x in l.split()], dtype = np.int64)

plt.figure(figsize=(12, 8))
plt.plot(x, y, 'bo', markersize=10, markeredgewidth=2, markeredgecolor='darkblue')
plt.xscale('log')
plt.yscale('log')
log_x = np.log10(x)
log_y = np.log10(y)
coeffs = np.polyfit(log_x, log_y, 1)
k, b = coeffs
plt.xlabel('log N', fontsize=14)
plt.ylabel('log T/ns', fontsize=14)
custom_xticks = [500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000]
custom_xtick_labels = [f'{np.log10(val):.2f}' for val in custom_xticks]
plt.xticks(custom_xticks, custom_xtick_labels, fontsize=12)
custom_yticks = [1e7, 1e8, 1e9, 1e10]
custom_ytick_labels = [f'{np.log10(val):.2f}' for val in custom_yticks]
plt.yticks(custom_yticks, custom_ytick_labels, fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)
plt.grid(True, which='major', linewidth=1, alpha=0.5)
print(k)
x_fit = np.logspace(np.log10(min(x)), np.log10(max(x)), 100)
y_fit = 10**b * x_fit**k
plt.plot(x_fit, y_fit, 'b-', linewidth=2)
plt.tight_layout()
plt.savefig('C1.pdf', bbox_inches='tight', facecolor='white')
plt.show()
# Out:
# 0.8784739748320022

# %%
#B1
import matplotlib.pyplot as plt
import numpy as np

x = np.array([500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000])
# y = np.array([4332247, 8783164, 42381837, 84682963 ,427510643, 852087504, 4303248626 ,8687155568 ])
with open('output_tres_rnd.txt', 'r') as f:
    for cl, l in enumerate(f):
        if cl == 1:
            y = np.array([int(x) for x in l.split()], dtype = np.int64)

plt.figure(figsize=(12, 8))
plt.plot(x, y, 'bo', markersize=10, markeredgewidth=2, markeredgecolor='darkblue')
plt.xscale('log')
plt.yscale('log')
log_x = np.log10(x)
log_y = np.log10(y)
coeffs = np.polyfit(log_x, log_y, 1)
k, b = coeffs
plt.xlabel('log N', fontsize=14)
plt.ylabel('log T/ns', fontsize=14)
custom_xticks = [500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000]
custom_xtick_labels = [f'{np.log10(val):.2f}' for val in custom_xticks]
plt.xticks(custom_xticks, custom_xtick_labels, fontsize=12)
custom_yticks = [1e7, 1e8, 1e9, 1e10]
custom_ytick_labels = [f'{np.log10(val):.2f}' for val in custom_yticks]
plt.yticks(custom_yticks, custom_ytick_labels, fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)
plt.grid(True, which='major', linewidth=1, alpha=0.5)
print(k)
x_fit = np.logspace(np.log10(min(x)), np.log10(max(x)), 100)
y_fit = 10**b * x_fit**k
plt.plot(x_fit, y_fit, 'b-', linewidth=2)
plt.tight_layout()
plt.savefig('B1.pdf', bbox_inches='tight', facecolor='white')
plt.show()
# Out:
# 0.999746000845212

# %%
#A1
import matplotlib.pyplot as plt
import numpy as np

x = np.array([500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000])
# y = np.array([4462776, 8933647, 43001174, 84993998, 451351647, 857635638, 4331915054, 8606982644 ])
with open('output_tres_rnd.txt', 'r') as f:
    for cl, l in enumerate(f):
        if cl == 2:
            y = np.array([int(x) for x in l.split()], dtype = np.int64)

plt.figure(figsize=(12, 8))
plt.plot(x, y, 'bo', markersize=10, markeredgewidth=2, markeredgecolor='darkblue')
plt.xscale('log')
plt.yscale('log')
log_x = np.log10(x)
log_y = np.log10(y)
coeffs = np.polyfit(log_x, log_y, 1)
k, b = coeffs
plt.xlabel('log N', fontsize=14)
plt.ylabel('log T/ns', fontsize=14)
custom_xticks = [500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000]
custom_xtick_labels = [f'{np.log10(val):.2f}' for val in custom_xticks]
plt.xticks(custom_xticks, custom_xtick_labels, fontsize=12)
custom_yticks = [1e7, 1e8, 1e9, 1e10]
custom_ytick_labels = [f'{np.log10(val):.2f}' for val in custom_yticks]
plt.yticks(custom_yticks, custom_ytick_labels, fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)
plt.grid(True, which='major', linewidth=1, alpha=0.5)
print(k)
x_fit = np.logspace(np.log10(min(x)), np.log10(max(x)), 100)
y_fit = 10**b * x_fit**k
plt.plot(x_fit, y_fit, 'b-', linewidth=2)
plt.tight_layout()
plt.savefig('A1.pdf', bbox_inches='tight', facecolor='white')
plt.show()
# Out:
# 0.9993717288777603

# %%
#A2
import matplotlib.pyplot as plt
import numpy as np

x = np.array([500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000])
# y = np.array([195471, 321734, 2121966, 3234958, 24170238, 50389775, 253540248, 285836773 ])
with open('output_tres_spc.txt', 'r') as f:
    for cl, l in enumerate(f):
        if cl == 2:
            y = np.array([int(x) for x in l.split()], dtype = np.int64)

plt.figure(figsize=(12, 8))
plt.plot(x, y, 'bo', markersize=10, markeredgewidth=2, markeredgecolor='darkblue')
plt.xscale('log')
plt.yscale('log')
log_x = np.log10(x)
log_y = np.log10(y)
coeffs = np.polyfit(log_x, log_y, 1)
k, b = coeffs
plt.xlabel('log N', fontsize=14)
plt.ylabel('log T/ns', fontsize=14)
custom_xticks = [500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000]
custom_xtick_labels = [f'{np.log10(val):.2f}' for val in custom_xticks]
plt.xticks(custom_xticks, custom_xtick_labels, fontsize=12)
custom_yticks = [1e+5, 1e+6,1e7, 1e8, 1e9, 1e10]
custom_ytick_labels = [f'{np.log10(val):.2f}' for val in custom_yticks]
plt.yticks(custom_yticks, custom_ytick_labels, fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)
plt.grid(True, which='major', linewidth=1, alpha=0.5)
print(k)
x_fit = np.logspace(np.log10(min(x)), np.log10(max(x)), 100)
y_fit = 10**b * x_fit**k
plt.plot(x_fit, y_fit, 'b-', linewidth=2)
plt.tight_layout()
plt.savefig('A2.pdf', bbox_inches='tight', facecolor='white')
plt.show()
# Out:
# 1.0162429979086536

# %%
#B2
import matplotlib.pyplot as plt
import numpy as np

x = np.array([500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000])
# y = np.array([141218, 419892, 2552169, 4249573, 22261800 ,39580848, 180019139, 364075063 ])
with open('output_tres_spc.txt', 'r') as f:
    for cl, l in enumerate(f):
        if cl == 1:
            y = np.array([int(x) for x in l.split()], dtype = np.int64)

plt.figure(figsize=(12, 8))
plt.plot(x, y, 'bo', markersize=10, markeredgewidth=2, markeredgecolor='darkblue')
plt.xscale('log')
plt.yscale('log')
log_x = np.log10(x)
log_y = np.log10(y)
coeffs = np.polyfit(log_x, log_y, 1)
k, b = coeffs
plt.xlabel('log N', fontsize=14)
plt.ylabel('log T/ns', fontsize=14)
custom_xticks = [500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000]
custom_xtick_labels = [f'{np.log10(val):.2f}' for val in custom_xticks]
plt.xticks(custom_xticks, custom_xtick_labels, fontsize=12)
custom_yticks = [1e+5, 1e+6, 1e7, 1e8, 1e9, 1e10]
custom_ytick_labels = [f'{np.log10(val):.2f}' for val in custom_yticks]
plt.yticks(custom_yticks, custom_ytick_labels, fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)
plt.grid(True, which='major', linewidth=1, alpha=0.5)
print(k)
x_fit = np.logspace(np.log10(min(x)), np.log10(max(x)), 100)
y_fit = 10**b * x_fit**k
plt.plot(x_fit, y_fit, 'b-', linewidth=2)
plt.tight_layout()
plt.savefig('B2.pdf', bbox_inches='tight', facecolor='white')
plt.show()
# Out:
# 1.0051328248210816

# %%
#C2
import matplotlib.pyplot as plt
import numpy as np

x = np.array([500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000])
# y = np.array([110361, 164958, 398568, 833504, 4222705, 3634047, 16126295, 27063000 ])
with open('output_tres_spc.txt', 'r') as f:
    for cl, l in enumerate(f):
        if cl == 0:
            y = np.array([int(x) for x in l.split()], dtype = np.int64)

plt.figure(figsize=(12, 8))
plt.plot(x, y, 'bo', markersize=10, markeredgewidth=2, markeredgecolor='darkblue')
plt.xscale('log')
plt.yscale('log')
log_x = np.log10(x)
log_y = np.log10(y)
plt.xlabel('log N', fontsize=14)
plt.ylabel('log T/ns', fontsize=14)
custom_xticks = [500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000]
custom_xtick_labels = [f'{np.log10(val):.2f}' for val in custom_xticks]
plt.xticks(custom_xticks, custom_xtick_labels, fontsize=12)
custom_yticks = [1e+4, 1e+5, 1e+6, 1e7, 1e8, 1e9, 1e10]
custom_ytick_labels = [f'{np.log10(val):.2f}' for val in custom_yticks]
plt.yticks(custom_yticks, custom_ytick_labels, fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)
plt.grid(True, which='major', linewidth=1, alpha=0.5)
u = np.delete(log_x, [0, 1])
v = np.delete(log_y, [0, 1])
c = np.polyfit(u, v, 1)
k1, b1 = c
print(k1)
x_fit = np.logspace(np.log10(min(x)), np.log10(max(x)), 100)
y_fit = 10**b1 * x_fit**k1
plt.plot(x_fit, y_fit, 'b-', linewidth=2)
plt.tight_layout()
plt.savefig('C2.pdf', bbox_inches='tight', facecolor='white')
plt.show()
# Out:
# 0.7584133175638007

# %%
#one
import matplotlib.pyplot as plt
import numpy as np

x = np.array([500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000])
# ys = np.array([2162533, 4299470, 21273643, 42480559, 215049494, 426865036, 2155039303 ,4449638352 ])
# yb = np.array([43564402, 49874358, 67325621, 72796231 ,98220683, 110569052 ,136815195 ,146256571 ])
with open('output_uno.txt', 'r') as f:
    for cl, l in enumerate(f):
        if cl == 0:
            ys = np.array([int(x) for x in l.split()], dtype = np.int64)

        if cl == 1:
            yb = np.array([int(x) for x in l.split()], dtype = np.int64)

y = yb/200
plt.figure(figsize=(12, 8))
plt.plot(x, ys, 'bo', markersize=10, markeredgewidth=2, markeredgecolor='darkblue')
plt.plot(x, y, 'ro', markersize=10, markeredgewidth=2, markeredgecolor='red')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('log N', fontsize=14)
plt.ylabel('log T/ns', fontsize=14)
custom_xticks = [500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000]
custom_xtick_labels = [f'{np.log10(val):.2f}' for val in custom_xticks]
plt.xticks(custom_xticks, custom_xtick_labels, fontsize=12)
custom_yticks = [1e5, 1e6, 1e7,  1e8, 1e9, 1e10]
custom_ytick_labels = [f'{np.log10(val):.2f}' for val in custom_yticks]
plt.yticks(custom_yticks, custom_ytick_labels, fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)
plt.grid(True, which='major', linewidth=1, alpha=0.5)
plt.tight_layout()
plt.savefig('1.both.pdf', bbox_inches='tight', facecolor='white')
plt.show()

# %%
#two
import matplotlib.pyplot as plt
import numpy as np

xs = np.array([500, 1000, 5000, 10000, 50000, 100000, 200000])
# y1 = np.array([2146000, 8532000, 207853000 ,823942000 ,20250292000, 79321725000, 327598910000 ])
xa = np.array([500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000])
# y2 = np.array([6000, 16000, 86000, 205000, 1143000, 1864000, 4649000, 20763000 ])
with open('output_dos.txt', 'r') as f:
    for cl, l in enumerate(f):
        if cl == 0:
            y1 = np.array([int(x) for x in l.split()], dtype = np.int64)

        if cl == 1:
            y2 = np.array([int(x) for x in l.split()], dtype = np.int64)

ys = y1*15
ya = y2*10000
plt.figure(figsize=(12, 8))
plt.plot(xs, ys, 'bo', markersize=10, markeredgewidth=2, markeredgecolor='darkblue')
plt.plot(xa, ya, 'ro', markersize=10, markeredgewidth=2, markeredgecolor='red')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('log N', fontsize=14)
plt.ylabel('log T/ns', fontsize=14)
custom_xticks = [500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000]
custom_xtick_labels = [f'{np.log10(val):.2f}' for val in custom_xticks]
plt.xticks(custom_xticks, custom_xtick_labels, fontsize=12)
custom_yticks = [1e7, 1e8, 1e9, 1e10, 1e11, 1e12, 1e13]
custom_ytick_labels = [f'{np.log10(val):.2f}' for val in custom_yticks]
plt.yticks(custom_yticks, custom_ytick_labels, fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)
plt.grid(True, which='major', linewidth=1, alpha=0.5)
plt.tight_layout()
plt.savefig('2.both.pdf', bbox_inches='tight', facecolor='white')
plt.show()

# %%
#three rnd
import matplotlib.pyplot as plt
import numpy as np

x = np.array([500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000])
# ya = np.array([4462776, 8933647, 43001174, 84993998, 451351647, 857635638, 4331915054, 8606982644 ])
# yb = np.array([4332247, 8783164, 42381837, 84682963 ,427510643, 852087504, 4303248626 ,8687155568 ])
# yc = np.array([4340219, 8602143, 42476518, 85223736 ,430178692 ,856074064, 4354902370, 8890960312 ])
with open('output_tres_rnd.txt', 'r') as f:
    for cl, l in enumerate(f):
        if cl == 0:
            yc = np.array([int(x) for x in l.split()], dtype = np.int64)
            
        if cl == 1:
            yb = np.array([int(x) for x in l.split()], dtype = np.int64)

        if cl == 2:
            ya = np.array([int(x) for x in l.split()], dtype = np.int64)

plt.figure(figsize=(12, 8))
plt.plot(x, ya, 'bo', markersize=10, markeredgewidth=2, markeredgecolor='darkblue')
plt.plot(x, yb, 'ro', markersize=10, markeredgewidth=2, markeredgecolor='red')
plt.plot(x, yc, 'go', markersize=10, markeredgewidth=2, markeredgecolor='green')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('log N', fontsize=14)
plt.ylabel('log T/ns', fontsize=14)
custom_xticks = [500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000]
custom_xtick_labels = [f'{np.log10(val):.2f}' for val in custom_xticks]
plt.xticks(custom_xticks, custom_xtick_labels, fontsize=12)
custom_yticks = [1e5, 1e6, 1e7,  1e8, 1e9, 1e10]
custom_ytick_labels = [f'{np.log10(val):.2f}' for val in custom_yticks]
plt.yticks(custom_yticks, custom_ytick_labels, fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)
plt.grid(True, which='major', linewidth=1, alpha=0.5)
plt.tight_layout()
plt.savefig('3.rnd.all.pdf', bbox_inches='tight', facecolor='white')
plt.show()
print(ya)
print(yb)
print(yc)
# Out:
# [   4230458    8644522   41651655   83337625  430795798  836386780
#  4209782482 8494837272]
# [   4217160    8519680   41596721   83273002  420091265  836262612
#  4185696460 8492010324]
# [  13164346   16520269   50087394   79150128  403567833  814335380
#  4261060084 8699367193]

# %%
#three spc
import matplotlib.pyplot as plt
import numpy as np

x = np.array([500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000])
# yc = np.array([110361, 164958, 398568, 833504, 4222705, 3634047, 16126295, 27063000 ])
# yb = np.array([141218, 419892, 2552169, 4249573, 22261800 ,39580848, 180019139, 364075063 ])
# ya = np.array([195471, 321734, 2121966, 3234958, 24170238, 50389775, 253540248, 285836773 ])
with open('output_tres_spc.txt', 'r') as f:
    for cl, l in enumerate(f):
        if cl == 0:
            yc = np.array([int(x) for x in l.split()], dtype = np.int64)

        if cl == 1:
            yb = np.array([int(x) for x in l.split()], dtype = np.int64)

        if cl == 2:
            ya = np.array([int(x) for x in l.split()], dtype = np.int64)

plt.figure(figsize=(12, 8))
plt.plot(x, ya, 'bo', markersize=10, markeredgewidth=2, markeredgecolor='darkblue')
plt.plot(x, yb, 'ro', markersize=10, markeredgewidth=2, markeredgecolor='red')
plt.plot(x, yc, 'go', markersize=10, markeredgewidth=2, markeredgecolor='green')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('log N', fontsize=14)
plt.ylabel('log T/ns', fontsize=14)
custom_xticks = [500, 1000, 5000, 10000, 50000, 100000, 500000, 1000000]
custom_xtick_labels = [f'{np.log10(val):.2f}' for val in custom_xticks]
plt.xticks(custom_xticks, custom_xtick_labels, fontsize=12)
custom_yticks = [1e5, 1e6, 1e7,  1e8, 1e9]
custom_ytick_labels = [f'{np.log10(val):.2f}' for val in custom_yticks]
plt.yticks(custom_yticks, custom_ytick_labels, fontsize=12)
plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)
plt.grid(True, which='major', linewidth=1, alpha=0.5)
plt.tight_layout()
plt.savefig('3.spc.all.pdf', bbox_inches='tight', facecolor='white')
plt.show()
